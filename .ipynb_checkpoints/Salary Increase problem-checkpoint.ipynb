# %% [markdown]
# ![perceptron.PNG](attachment:perceptron.PNG)

# %% [markdown]
# ## Inputs, outputs and weights

# %%
import numpy as np

# %%
inputs = np.array([[18,2], [20,3], [21,4], 
                   [35,15], [36,16], [38,18]])

# %%
outputs = np.array([0, 0, 0, 1, 1, 1])

# %%
weights = np.array([0.0, 0.0])

# %%
learning_rate = 0.1

# %% [markdown]
# ## Step function

# %%
def step_function(sum):
    if (sum >=1):
        return 1
    return 0

# %% [markdown]
# ## Calculate output

# %%
def calculate_output(instance):
    s = instance.dot(weights)
    return step_function(s)

# %% [markdown]
# ## Train

# %%
def train():
    total_error = 1
    while (total_error != 0):
        total_error = 0
        for i in range(len(outputs)):
            prediction = calculate_output(inputs[i])
            error = abs(outputs[i] - prediction)
            total_error += error
            if error > 0:
                for j in range(len(weights)):
                    weights[j] = weights[j] + (learning_rate * inputs[i][j] * error)
                    print(' Weights update : ' + str(weights[j]))
        print('Total error : ' + str(total_error))

# %% [markdown]
# ## Graph

# %%
import pandas as pd

# %%
df1 = pd.DataFrame(data=inputs, columns=['age', 'educational'])

# %%
df1
# Out:
#    age  educational
# 0   18            2
# 1   20            3
# 2   21            4
# 3   35           15
# 4   36           16
# 5   38           18

# %%
df2 = pd.DataFrame(data=outputs, columns=['class'])

# %%
df2
# Out:
#    class
# 0      0
# 1      0
# 2      0
# 3      1
# 4      1
# 5      1

# %%
df = pd.concat([df1,df2], axis = 1)

# %%
import seaborn as sns
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
sns.relplot(x = 'age', y= 'educational', data = df, hue= 'class')

# %% [markdown]
# ## MinMax scalar

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()
inputs = scaler.fit_transform(inputs)

# %%
inputs
# Out:
# array([[0.    , 0.    ],
#        [0.1   , 0.0625],
#        [0.15  , 0.125 ],
#        [0.85  , 0.8125],
#        [0.9   , 0.875 ],
#        [1.    , 1.    ]])

# %%
train()
# Out:
#  Weights update : 0.085
#  Weights update : 0.08125
#  Weights update : 0.17500000000000002
#  Weights update : 0.16875
#  Weights update : 0.275
#  Weights update : 0.26875000000000004
# Total error : 3
#  Weights update : 0.36000000000000004
#  Weights update : 0.35000000000000003
#  Weights update : 0.45000000000000007
#  Weights update : 0.43750000000000006
#  Weights update : 0.55
#  Weights update : 0.5375000000000001
# Total error : 3
#  Weights update : 0.635
#  Weights update : 0.6187500000000001
# Total error : 1
# Total error : 0
